# %%
#dependencies
import pandas as pd

# %%
#importing data
school_cvspath = 'Resources\schools_complete.csv'
student_cvspath = 'Resources\students_complete.csv'

# %%
#Using Pandas to read data
school_data = pd.read_csv(school_cvspath)
student_data = pd.read_csv(student_cvspath)

# %%
#initial viewing of data
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#initial viewing of data
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#Checking columns actual names
student_data.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score'],
#       dtype='object')

# %%
#Checking columns actual names
school_data.columns
# Out:
# Index(['School ID', 'school_name', 'type', 'size', 'budget'], dtype='object')

# %%
#Cleaning up column names.
student_data = student_data.rename(columns={
    'student_name' : 'Student Name',
    'gender' : 'Gender',
    'grade' : 'Grade',
    'school_name' : 'School Name',
    'reading_score' : 'Reading Score',
    'math_score' : "Math Score"
})

# %%
#Rechecking cleaned data
student_data.head()
# Out:
#    Student ID       Student Name Gender Grade        School Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    Reading Score  Math Score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#Cleaning up column names.
school_data = school_data.rename(columns={
    'school_name' : 'School Name',
    'type' : 'Type',
    'size' : 'Size',
    'budget' : 'Budget',
})

# %%
#Rechecking cleaned data
school_data.head()
# Out:
#    School ID            School Name      Type  Size   Budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#Initial Statistics inquiries

#total_students = student_data['Student Name'].count()
#does not account for duplicates. Code below accounts for duplicates. Although both produce the same answer in this case because there was no duplicates.
total_students = len(student_data['Student Name'].unique())
student_info = student_data['Student Name'].value_counts()
best_reading_score = student_data['Reading Score'].max()
worst_reading_score = student_data['Reading Score'].min()
avg_reading_score = student_data['Reading Score'].mean()
best_math_score = student_data['Math Score'].max()
worst_math_score = student_data['Math Score'].min()
avg_math_score = student_data['Math Score'].mean()

print(total_students)
print(student_info)
print(best_reading_score)
print(worst_reading_score)
print(avg_reading_score)
print(best_math_score)
print(worst_math_score)
print(avg_math_score)
# Out:
# 32715
# Michael Smith             26
# Michael Williams          16
# David Johnson             16
# David Smith               15
# Daniel Johnson            14
# Michael Brown             13
# Michael Johnson           13
# Michael Martinez          12
# Jessica Smith             11
# Jennifer Anderson         11
# Lisa Smith                11
# Michelle Smith            11
# Robert Jones              10
# Michael Miller            10
# John Smith                10
# John Johnson              10
# James Smith               10
# Amanda Johnson            10
# Michael Davis             10
# Thomas Smith              10
# James Williams             9
# Robert Smith               9
# Jessica Johnson            9
# Jennifer Johnson           9
# William Smith              9
# David Miller               9
# Christopher Williams       9
# Matthew Smith              9
# Michael Clark              9
# Joshua Smith               8
#                           ..
# Shannon Griffin            1
# ...

# %%
#Rounding Average - Data Cleanup
avg_reading_score = round(avg_reading_score, 0)
avg_math_score = round(avg_math_score, 0)

print(avg_reading_score)
print(avg_math_score)
# Out:
# 82.0
# 79.0

# %%
#Additional Statistics
budget = school_data['Budget'].count()
print(budget)
budget_total = school_data['Budget'].sum()
budget_total
# Out:
# 15
# 24649428

# %%
#Per student budget
per_student = total_students / budget_total
per_student
# Out:
# 0.0013272113251471798

# %%
#merging on School Name for single data set.
schools_merge = pd.merge(student_data, school_data, how='outer', on="School Name")
schools_merge.head()
# Out:
#    Student ID       Student Name Gender Grade        School Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    Reading Score  Math Score  School ID      Type  Size   Budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# More stats
#total_schools = school_data["School Name"].count()
#does not account for duplicates. Code below accounts for duplicates. Although both produce the same answer in this case because there was no duplicates.
total_schools = len(school_data["School ID"].unique())
print(total_schools)

#Calculate the percentage of students with a passing math score (70 or greater)
#Calculate the percentage of students with a passing reading score (70 or greater)
#Create 1s  for the passing students by math or reading. 0 otherwise. And take the mean to get the average. It will give the percent of the passing students.
student_data["math_pass"] = student_data["Math Score"] >= 70
student_data["reading_pass"] = student_data["Reading Score"] >= 70
percent_passing_math = ((student_data["math_pass"]).mean())*100
percent_passing_reading = ((student_data["reading_pass"]).mean())*100
percent_passing_math = round(percent_passing_math, 2)
percent_passing_reading = round(percent_passing_reading, 2)
overall_pass = (percent_passing_reading + percent_passing_math ) / 2
print(percent_passing_reading)
print(percent_passing_math)
print(overall_pass)
# Out:
# 15
# 85.81
# 74.98
# 80.39500000000001

# %%
# Creating a summary DataFrame using above values
district_summary_df = pd.DataFrame({
    'Total Schools' : [total_schools],
    'Total Students' : [total_students],
    'Total Budget' : [budget_total],
    'Average Math Score' : [avg_math_score],
    'Average Reading Score' : [avg_reading_score],
    '% Passing Math' : [percent_passing_math],
    '% Passing Reading' : [percent_passing_reading],
    '% Overall Passing Rate' : [overall_pass],
})

#Formatting.
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,.2f}".format)
district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:,.2f}%".format)
district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:,.2f}%".format)
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:}%".format)
district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:}%".format)
district_summary_df["% Overall Passing Rate"] = district_summary_df["% Overall Passing Rate"].map("{:,.2f}%".format)

district_summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         32,715  $24,649,428.00              79.0%
#
#   Average Reading Score % Passing Math % Passing Reading  \
# 0                 82.0%         74.98%            85.81%
#
#   % Overall Passing Rate
# 0                 80.40%

# %%
#before Groupby writing new data:
schools_merge["Passing Math"] = schools_merge["Math Score"] >= 70
schools_merge["Passing Reading"] = schools_merge["Reading Score"] >= 70

schools_merge
# Out:
#        Student ID         Student Name Gender Grade         School Name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
# Using GroupBy in order to separate the data
grouped_schools_df = schools_merge.groupby(['School Name']).mean()
print(grouped_schools_df)

#grouped_schools_df['Student ID'].count().head(10)
#grouped_schools_df.count().head(10)
grouped_schools_df.head()
# Out:
#                        Student ID  Reading Score  Math Score  School ID  \
# School Name
# Bailey High School        20358.5      81.033963   77.048432        7.0
# Cabrera High School       16941.5      83.975780   83.061895        6.0
# Figueroa High School       4391.0      81.158020   76.711767        1.0
# Ford High School          36165.0      80.746258   77.102592       13.0
# Griffin High School       12995.5      83.816757   83.351499        4.0
# Hernandez High School      9944.0      80.934412   77.289752        3.0
# Holden High School        23060.0      83.814988   83.803279        8.0
# Huang High School          1458.0      81.182722   76.629414        0.0
# Johnson High School       32415.0      80.966394   77.072464       12.0
# Pena High School          23754.5      84.044699   83.839917        9.0
# Rodriguez High School     28035.0      80.744686   76.842711       11.0
# Shelton High School        6746.0      83.725724   83.359455        2.0
# ...

# %%
grouped_schools_df['Per Student'] = grouped_schools_df['Budget']/grouped_schools_df['Size']
grouped_schools_df["Average Math Score"] = grouped_schools_df['Math Score'].mean()
grouped_schools_df["Average Reading Score"] = grouped_schools_df['Reading Score'].mean()
grouped_schools_df["Passing Math"] = round(grouped_schools_df["Passing Math"]*100,2)
grouped_schools_df["Passing Reading"] = round(grouped_schools_df["Passing Reading"]*100,2)
grouped_schools_df["Overall Passing Rate"] = (grouped_schools_df["Passing Math"] + grouped_schools_df["Passing Reading"])/2
grouped_schools_df.head()
# Out:
#                       Student ID  Reading Score  Math Score  School ID  \
# School Name
# Bailey High School       20358.5      81.033963   77.048432        7.0
# Cabrera High School      16941.5      83.975780   83.061895        6.0
# Figueroa High School      4391.0      81.158020   76.711767        1.0
# Ford High School         36165.0      80.746258   77.102592       13.0
# Griffin High School      12995.5      83.816757   83.351499        4.0
#
#                         Size     Budget  Passing Math  Passing Reading  \
# School Name
# Bailey High School    4976.0  3124928.0         66.68            81.93
# Cabrera High School   1858.0  1081356.0         94.13            97.04
# Figueroa High School  2949.0  1884411.0         65.99            80.74
# Ford High School      2739.0  1763916.0         68.31            79.30
# Griffin High School   1468.0   917500.0         93.39            97.14
#
#                       Per Student  Average Math Score  Average Reading Score  \
# ...

# %%
grouped_schools_df.columns.tolist()
# Out:
# ['Student ID',
#  'Reading Score',
#  'Math Score',
#  'School ID',
#  'Size',
#  'Budget',
#  'Passing Math',
#  'Passing Reading',
#  'Per Student',
#  'Average Math Score',
#  'Average Reading Score',
#  'Overall Passing Rate']

# %%
#Not Sure Why Type dropped off... Reimporting it.
grouped_schools = pd.merge(grouped_schools_df, school_data, how='outer', on='School ID')

grouped_schools.head()
# Out:
#    Student ID  Reading Score  Math Score  School ID  Size_x   Budget_x  \
# 0     20358.5      81.033963   77.048432        7.0  4976.0  3124928.0
# 1     16941.5      83.975780   83.061895        6.0  1858.0  1081356.0
# 2      4391.0      81.158020   76.711767        1.0  2949.0  1884411.0
# 3     36165.0      80.746258   77.102592       13.0  2739.0  1763916.0
# 4     12995.5      83.816757   83.351499        4.0  1468.0   917500.0
#
#    Passing Math  Passing Reading  Per Student  Average Math Score  \
# 0         66.68            81.93        628.0            80.43253
# 1         94.13            97.04        582.0            80.43253
# 2         65.99            80.74        639.0            80.43253
# 3         68.31            79.30        644.0            80.43253
# 4         93.39            97.14        625.0            80.43253
#
#    Average Reading Score  Overall Passing Rate           School Name  \
# ...

# %%
grouped_schools.columns.tolist()
# Out:
# ['Student ID',
#  'Reading Score',
#  'Math Score',
#  'School ID',
#  'Size_x',
#  'Budget_x',
#  'Passing Math',
#  'Passing Reading',
#  'Per Student',
#  'Average Math Score',
#  'Average Reading Score',
#  'Overall Passing Rate',
#  'School Name',
#  'Type',
#  'Size_y',
#  'Budget_y']

# %%
del grouped_schools['Size_y']
del grouped_schools['Budget_y']
grouped_schools.head(10)
# Out:
#    Student ID  Reading Score  Math Score  School ID  Size_x   Budget_x  \
# 0     20358.5      81.033963   77.048432        7.0  4976.0  3124928.0
# 1     16941.5      83.975780   83.061895        6.0  1858.0  1081356.0
# 2      4391.0      81.158020   76.711767        1.0  2949.0  1884411.0
# 3     36165.0      80.746258   77.102592       13.0  2739.0  1763916.0
# 4     12995.5      83.816757   83.351499        4.0  1468.0   917500.0
# 5      9944.0      80.934412   77.289752        3.0  4635.0  3022020.0
# 6     23060.0      83.814988   83.803279        8.0   427.0   248087.0
# 7      1458.0      81.182722   76.629414        0.0  2917.0  1910635.0
# 8     32415.0      80.966394   77.072464       12.0  4761.0  3094650.0
# 9     23754.5      84.044699   83.839917        9.0   962.0   585858.0
#
#    Passing Math  Passing Reading  Per Student  Average Math Score  \
# 0         66.68            81.93        628.0            80.43253
# ...

# %%
#reorganizing columns and removing Student ID

grouped_schools = grouped_schools[['School Name', 'School ID', 'Type', 'Size_x', 'Budget_x', 'Per Student', 'Average Math Score', 'Average Reading Score', 'Passing Math', 'Passing Reading', 'Overall Passing Rate']]
grouped_schools.head(10)
# Out:
#              School Name  School ID      Type  Size_x   Budget_x  Per Student  \
# 0     Bailey High School        7.0  District  4976.0  3124928.0        628.0
# 1    Cabrera High School        6.0   Charter  1858.0  1081356.0        582.0
# 2   Figueroa High School        1.0  District  2949.0  1884411.0        639.0
# 3       Ford High School       13.0  District  2739.0  1763916.0        644.0
# 4    Griffin High School        4.0   Charter  1468.0   917500.0        625.0
# 5  Hernandez High School        3.0  District  4635.0  3022020.0        652.0
# 6     Holden High School        8.0   Charter   427.0   248087.0        581.0
# 7      Huang High School        0.0  District  2917.0  1910635.0        655.0
# 8    Johnson High School       12.0  District  4761.0  3094650.0        650.0
# 9       Pena High School        9.0   Charter   962.0   585858.0        609.0
#
#    Average Math Score  Average Reading Score  Passing Math  Passing Reading  \
# ...

# %%
#Cleaning up column names.
grouped_schools = grouped_schools.rename(columns={
    'Size_x' : 'Total Students',
    'Budget_x' : 'Total School Budget',
    'Per Student' : 'Per Student Budget'
})

grouped_schools.head(10)
# Out:
#              School Name  School ID      Type  Total Students  \
# 0     Bailey High School        7.0  District          4976.0
# 1    Cabrera High School        6.0   Charter          1858.0
# 2   Figueroa High School        1.0  District          2949.0
# 3       Ford High School       13.0  District          2739.0
# 4    Griffin High School        4.0   Charter          1468.0
# 5  Hernandez High School        3.0  District          4635.0
# 6     Holden High School        8.0   Charter           427.0
# 7      Huang High School        0.0  District          2917.0
# 8    Johnson High School       12.0  District          4761.0
# 9       Pena High School        9.0   Charter           962.0
#
#    Total School Budget  Per Student Budget  Average Math Score  \
# 0            3124928.0               628.0            80.43253
# 1            1081356.0               582.0            80.43253
# 2            1884411.0               639.0            80.43253
# ...

# %%
#formatting
#grouped_schools['Total Students'] = grouped_schools['Total Students'].map("{:,.0f}".format)
grouped_schools['Total School Budget'] = grouped_schools['Total School Budget'].map("${:,.2f}".format)
#grouped_schools['Per Student Budget'] = grouped_schools['Per Student Budget'].map("${:,.2f}".format)
grouped_schools["Average Math Score"] = round(grouped_schools["Average Math Score"],2)
grouped_schools["Average Reading Score"] = round(grouped_schools["Average Reading Score"],2)
#grouped_schools["Average Math Score"] = grouped_schools["Average Math Score"].map("{:}%".format)
#grouped_schools["Average Reading Score"] = grouped_schools["Average Reading Score"].map("{:}%".format)
grouped_schools
# Out:
#               School Name  School ID      Type  Total Students  \
# 0      Bailey High School        7.0  District          4976.0
# 1     Cabrera High School        6.0   Charter          1858.0
# 2    Figueroa High School        1.0  District          2949.0
# 3        Ford High School       13.0  District          2739.0
# 4     Griffin High School        4.0   Charter          1468.0
# 5   Hernandez High School        3.0  District          4635.0
# 6      Holden High School        8.0   Charter           427.0
# 7       Huang High School        0.0  District          2917.0
# 8     Johnson High School       12.0  District          4761.0
# 9        Pena High School        9.0   Charter           962.0
# 10  Rodriguez High School       11.0  District          3999.0
# 11    Shelton High School        2.0   Charter          1761.0
# 12     Thomas High School       14.0   Charter          1635.0
# 13     Wilson High School        5.0   Charter          2283.0
# ...

# %%
#Sort and display the top five schools in overall passing rate

top_five_schools = grouped_schools.sort_values(["Overall Passing Rate"], ascending=False)
top_five_schools.head()
# Out:
#             School Name  School ID     Type  Total Students  \
# 1   Cabrera High School        6.0  Charter          1858.0
# 12   Thomas High School       14.0  Charter          1635.0
# 9      Pena High School        9.0  Charter           962.0
# 4   Griffin High School        4.0  Charter          1468.0
# 13   Wilson High School        5.0  Charter          2283.0
#
#    Total School Budget  Per Student Budget  Average Math Score  \
# 1        $1,081,356.00               582.0               80.43
# 12       $1,043,130.00               638.0               80.43
# 9          $585,858.00               609.0               80.43
# 4          $917,500.00               625.0               80.43
# 13       $1,319,574.00               578.0               80.43
#
#     Average Reading Score  Passing Math  Passing Reading  Overall Passing Rate
# 1                   82.53         94.13            97.04                95.585
# ...

# %%
#Sort and display the worst five schools in overall passing rate

worst_five_schools = grouped_schools.sort_values(["Overall Passing Rate"], ascending=True)
worst_five_schools.head()
# Out:
#               School Name  School ID      Type  Total Students  \
# 10  Rodriguez High School       11.0  District          3999.0
# 2    Figueroa High School        1.0  District          2949.0
# 7       Huang High School        0.0  District          2917.0
# 8     Johnson High School       12.0  District          4761.0
# 3        Ford High School       13.0  District          2739.0
#
#    Total School Budget  Per Student Budget  Average Math Score  \
# 10       $2,547,363.00               637.0               80.43
# 2        $1,884,411.00               639.0               80.43
# 7        $1,910,635.00               655.0               80.43
# 8        $3,094,650.00               650.0               80.43
# 3        $1,763,916.00               644.0               80.43
#
#     Average Reading Score  Passing Math  Passing Reading  Overall Passing Rate
# 10                  82.53         66.37            80.22                73.295
# ...

# %%
#Pandas series for each grade. Grouped each series by school.
#Math
nineth_grade = schools_merge[schools_merge["Grade"] == "9th"].groupby("School Name").mean()["Math Score"]
tenth_grade = schools_merge[schools_merge["Grade"] == "10th"].groupby("School Name").mean()["Math Score"]
eleventh_grade = schools_merge[schools_merge["Grade"] == "11th"].groupby("School Name").mean()["Math Score"]
twelveth_grade = schools_merge[schools_merge["Grade"] == "12th"].groupby("School Name").mean()["Math Score"]

#Combine the series into a dataframe
math_grade_dataframe = pd.DataFrame({"Ninth Grade":nineth_grade, "Tenth Grade":tenth_grade, 
                                     "Eleventh Grade":eleventh_grade, "Twelveth Grade":twelveth_grade})            

#formatting

math_grade_dataframe[["Ninth Grade","Tenth Grade","Eleventh Grade","Twelveth Grade"]] = math_grade_dataframe[["Ninth Grade","Tenth Grade","Eleventh Grade","Twelveth Grade"]].applymap("{:.2f}".format)

#Display

math_grade_dataframe
# Out:
#                       Ninth Grade Tenth Grade Eleventh Grade Twelveth Grade
# School Name
# Bailey High School          77.08       77.00          77.52          76.49
# Cabrera High School         83.09       83.15          82.77          83.28
# Figueroa High School        76.40       76.54          76.88          77.15
# Ford High School            77.36       77.67          76.92          76.18
# Griffin High School         82.04       84.23          83.84          83.36
# Hernandez High School       77.44       77.34          77.14          77.19
# Holden High School          83.79       83.43          85.00          82.86
# Huang High School           77.03       75.91          76.45          77.23
# Johnson High School         77.19       76.69          77.49          76.86
# Pena High School            83.63       83.37          84.33          84.12
# Rodriguez High School       76.86       76.61          76.40          77.69
# ...

# %%
#Pandas series for each grade. Grouped each series by school.
#Reading
nineth_grade = schools_merge[schools_merge["Grade"] == "9th"].groupby("School Name").mean()["Reading Score"]
tenth_grade = schools_merge[schools_merge["Grade"] == "10th"].groupby("School Name").mean()["Reading Score"]
eleventh_grade = schools_merge[schools_merge["Grade"] == "11th"].groupby("School Name").mean()["Reading Score"]
twelveth_grade = schools_merge[schools_merge["Grade"] == "12th"].groupby("School Name").mean()["Reading Score"]

#Combine the series into a dataframe
reading_grade_dataframe = pd.DataFrame({"Ninth Grade":nineth_grade, "Tenth Grade":tenth_grade, 
                                     "Eleventh Grade":eleventh_grade, "Twelveth Grade":twelveth_grade})            

#formatting

reading_grade_dataframe[["Ninth Grade","Tenth Grade","Eleventh Grade","Twelveth Grade"]] = reading_grade_dataframe[["Ninth Grade","Tenth Grade","Eleventh Grade","Twelveth Grade"]].applymap("{:.2f}".format)

#Display

reading_grade_dataframe
# Out:
#                       Ninth Grade Tenth Grade Eleventh Grade Twelveth Grade
# School Name
# Bailey High School          81.30       80.91          80.95          80.91
# Cabrera High School         83.68       84.25          83.79          84.29
# Figueroa High School        81.20       81.41          80.64          81.38
# Ford High School            80.63       81.26          80.40          80.66
# Griffin High School         83.37       83.71          84.29          84.01
# Hernandez High School       80.87       80.66          81.40          80.86
# Holden High School          83.68       83.32          83.82          84.70
# Huang High School           81.29       81.51          81.42          80.31
# Johnson High School         81.26       80.77          80.62          81.23
# Pena High School            83.81       83.61          84.34          84.59
# Rodriguez High School       80.99       80.63          80.86          80.38
# ...

# %%
help(pd.cut)
# Out:
# Help on function cut in module pandas.core.reshape.tile:
#
# cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise')
#     Bin values into discrete intervals.
#
#     Use `cut` when you need to segment and sort data values into bins. This
#     function is also useful for going from a continuous variable to a
#     categorical variable. For example, `cut` could convert ages to groups of
#     age ranges. Supports binning into an equal number of bins, or a
#     pre-specified array of bins.
#
#     Parameters
#     ----------
#     x : array-like
#         The input array to be binned. Must be 1-dimensional.
#     bins : int, sequence of scalars, or pandas.IntervalIndex
#         The criteria to bin by.
#
#         * int : Defines the number of equal-width bins in the range of `x`. The
#           range of `x` is extended by .1% on each side to include the minimum
#           and maximum values of `x`.
# ...

# %%
# Using 4 reasonable bins to group school spending. 
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]


grouped_schools["Spending Ranges (Per Student)"] = pd.cut(grouped_schools["Per Student Budget"], spending_bins, labels=group_names)

schools_spending_grouped = grouped_schools.groupby("Spending Ranges (Per Student)").mean() 

#Remove the unwanted columns
del schools_spending_grouped['School ID']
del schools_spending_grouped['Per Student Budget']

schools_spending_grouped
# Out:
#                                Total Students  Average Math Score  \
# Spending Ranges (Per Student)
# <$585                             1592.000000               80.43
# $585-615                          1361.500000               80.43
# $615-645                          2961.000000               80.43
# $645-675                          4104.333333               80.43
#
#                                Average Reading Score  Passing Math  \
# Spending Ranges (Per Student)
# <$585                                          82.53     93.460000
# $585-615                                       82.53     94.230000
# $615-645                                       82.53     75.668333
# $645-675                                       82.53     66.163333
#
#                                Passing Reading  Overall Passing Rate
# Spending Ranges (Per Student)
# <$585                                96.610000             95.035000
# ...

# %%
# Using 4 reasonable bins to group school size. 
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

grouped_schools["School Size"] = pd.cut(grouped_schools["Total Students"], size_bins, labels=group_names)

schools_size_grouped = grouped_schools.groupby("School Size").mean() 

#Remove the unwanted columns
del schools_size_grouped['School ID']
del schools_size_grouped['Total Students']
del schools_size_grouped['Per Student Budget']

schools_size_grouped
# Out:
#                     Average Math Score  Average Reading Score  Passing Math  \
# School Size
# Small (<1000)                    80.43                  82.53      93.55000
# Medium (1000-2000)               80.43                  82.53      93.59800
# Large (2000-5000)                80.43                  82.53      69.96375
#
#                     Passing Reading  Overall Passing Rate
# School Size
# Small (<1000)              96.10000                94.825
# Medium (1000-2000)         96.79000                95.194
# Large (2000-5000)          82.76625                76.365

# %%
#Type view
schools_type_grouped = grouped_schools.groupby("Type").mean()

#Remove the unwanted columns
del schools_type_grouped['School ID']
del schools_type_grouped['Total Students']
del schools_type_grouped['Per Student Budget']

schools_type_grouped
# Out:
#           Average Math Score  Average Reading Score  Passing Math  \
# Type
# Charter                80.43                  82.53     93.620000
# District               80.43                  82.53     66.548571
#
#           Passing Reading  Overall Passing Rate
# Type
# Charter         96.586250             95.103125
# District        80.798571             73.673571

# %%
#Obersvation 1:

#Charter Schools is majorly outperforming district schools. 95% vs 73% is a huge difference. We don't know what is driving that. We have no information on number of teachers, teacher salary, class times, subjects within math / reading, methods of teaching or even Zip Codes for students.
#However, the difference is large enough that one should probably inquire  further.

# %%
#Observation #2

#Size there seems to be a maximum at least wat which a drop starts to occur... over 2000 it drops. Perhaps further investigation is warranted. Is it because funds on different subjects become too spread?
